# %% [markdown]
# Copyright (c) 2021, salesforce.com, inc.
# All rights reserved.
# SPDX-License-Identifier: BSD-3-Clause
# For full license text, see the LICENSE file in the repo root or https://opensource.org/licenses/BSD-3-Clause

# %% [markdown]
# ### Colab
#
# Try this notebook on [Colab](http://colab.research.google.com/github/salesforce/ai-economist/blob/master/tutorials/multi_agent_training_with_rllib.ipynb).

# %% [markdown]
# ### Prerequisites
# It is helpful to be familiar with **Foundation**, a multi-agent economic simulator built for the AI Economist ([paper here](https://arxiv.org/abs/2004.13332)). If you haven't worked with Foundation before, we highly recommend taking a look at our other tutorials:
#
# - [Foundation: the Basics](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_basic.ipynb)
# - [Extending Foundation](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_advanced.ipynb)
# - [Optimal Taxation Theory and Simulation](https://github.com/salesforce/ai-economist/blob/master/tutorials/optimal_taxation_theory_and_simulation.ipynb)

# %% [markdown]
# ## Introduction

# %% [markdown]
# Welcome! This tutorial is the first of a series on doing distributed multi-agent reinforcement learning (MARL). Here, we specifically demonstrate how to integrate our multi-agent economic simulation, [Foundation](https://github.com/salesforce/ai-economist/tree/master/ai_economist/foundation), with [RLlib](https://github.com/ray-project/ray/tree/master/rllib), an open-source library for reinforcement learning. We chose to use RLlib, as it provides an easy-to-use and flexible library for MARL. A detailed documentation on RLlib is available [here](https://docs.ray.io/en/master/rllib.html).
#
# We put together these tutorial notebook with the following key goals in mind:
# - Provide an exposition to MARL. While there are many libraries and references out there for single-agent RL training, MARL training is not discussed as much, and there aren't many multi-agent rl libraries.
# - Provide reference starting code to perform MARL training so the AI Economist community can focus more on building meaningful extensions to Foundation and better-performant algorithms.
#
# We will cover the following concepts in this tutorial:
# 1. Adding an *environment wrapper* to make the economic simulation compatible with RLlib.
# 2. Creating a *trainer* object that holds the (multi-agent) policies for environment interaction.
# 3. Training all the agents in the economic simulation.
# 4. Generate a rollout using the trainer object and visualize it.

# %% [markdown]
# ### Dependencies:
# You can install the ai-economist package using
# - the pip package manager OR
# - by cloning the ai-economist package and installing the requirements (we shall use this when running on Colab):

# %%
import os, signal, sys, time
IN_COLAB = 'google.colab' in sys.modules
# Out:
# Requirement already satisfied: ai-economist in /home/bahain/forl/AI_Econ (1.7.1)
# Requirement already satisfied: appdirs==1.4.4 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.4.4)
# Requirement already satisfied: appnope==0.1.2 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.1.2)
# Requirement already satisfied: argon2-cffi==20.1.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (20.1.0)
# Requirement already satisfied: astroid==2.5.6 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2.5.6)
# Requirement already satisfied: async-generator==1.10 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.10)
# Requirement already satisfied: attrs==21.2.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (21.2.0)
# Requirement already satisfied: backcall==0.2.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.9.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (4.9.3)
# Requirement already satisfied: black==21.5b1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (21.5b1)
# Requirement already satisfied: bleach==3.3.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (3.3.0)
# Requirement already satisfied: bs4==0.0.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.0.1)
# Requirement already satisfied: certifi==2020.12.5 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2020.12.5)
# Requirement already satisfied: cffi==1.14.5 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.14.5)
# Requirement already satisfied: chardet==4.0.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (4.0.0)
# Requirement already satisfied: click==8.0.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (8.0.1)
# Requirement already satisfied: cycler==0.10.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.10.0)
# Requirement already satisfied: decorator==5.0.9 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (5.0.9)
# Requirement already satisfied: defusedxml==0.7.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.7.1)
# Requirement already satisfied: entrypoints==0.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.3)
# Requirement already satisfied: et-xmlfile==1.1.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.1.0)
# Requirement already satisfied: flake8==3.9.2 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (3.9.2)
# Requirement already satisfied: GPUtil==1.4.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.4.0)
# Requirement already satisfied: idna==2.10 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2.10)
# Requirement already satisfied: iniconfig==1.1.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.1.1)
# Requirement already satisfied: ipykernel==5.5.5 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (5.5.5)
# Requirement already satisfied: ipython==7.31.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (7.31.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.2.0)
# Requirement already satisfied: ipywidgets==7.6.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (7.6.3)
# Requirement already satisfied: isort==5.8.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (5.8.0)
# Requirement already satisfied: jedi==0.18.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.18.0)
# Requirement already satisfied: Jinja2==3.0.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (3.0.1)
# Requirement already satisfied: jsonschema==3.2.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (3.2.0)
# Requirement already satisfied: jupyter==1.0.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.0.0)
# Requirement already satisfied: jupyter-client==6.1.12 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (6.1.12)
# Requirement already satisfied: jupyter-console==6.4.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (6.4.0)
# Requirement already satisfied: jupyter-core==4.7.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (4.7.1)
# Requirement already satisfied: jupyterlab-pygments==0.1.2 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.1.2)
# Requirement already satisfied: jupyterlab-widgets==1.0.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.0.0)
# Requirement already satisfied: kiwisolver==1.3.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.3.1)
# Requirement already satisfied: lazy-object-proxy==1.6.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.6.0)
# Requirement already satisfied: lz4==3.1.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (3.1.3)
# Requirement already satisfied: MarkupSafe==2.0.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2.0.1)
# Requirement already satisfied: matplotlib==3.2.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (3.2.1)
# Requirement already satisfied: matplotlib-inline==0.1.2 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.1.2)
# Requirement already satisfied: mccabe==0.6.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.6.1)
# Requirement already satisfied: mistune==0.8.4 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.8.4)
# Requirement already satisfied: mypy-extensions==0.4.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.4.3)
# Requirement already satisfied: nbclient==0.5.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.5.3)
# Requirement already satisfied: nbconvert==6.0.7 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (6.0.7)
# Requirement already satisfied: nbformat==5.1.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (5.1.3)
# Requirement already satisfied: nest-asyncio==1.5.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.5.1)
# Requirement already satisfied: notebook==6.4.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (6.4.1)
# Requirement already satisfied: numpy==1.21.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.21.0)
# Requirement already satisfied: openpyxl==3.0.7 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (3.0.7)
# Requirement already satisfied: packaging==20.9 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (20.9)
# Requirement already satisfied: pandas==1.2.4 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.2.4)
# Requirement already satisfied: pandocfilters==1.4.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.4.3)
# Requirement already satisfied: parso==0.8.2 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.8.2)
# Requirement already satisfied: pathspec==0.8.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.8.1)
# Requirement already satisfied: pexpect==4.8.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.7.5)
# Requirement already satisfied: Pillow==9.0.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (9.0.1)
# Requirement already satisfied: pluggy==0.13.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.13.1)
# Requirement already satisfied: prometheus-client==0.10.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.10.1)
# Requirement already satisfied: prompt-toolkit==3.0.18 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (3.0.18)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.7.0)
# Requirement already satisfied: py==1.10.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.10.0)
# Requirement already satisfied: pycodestyle==2.7.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2.7.0)
# Requirement already satisfied: pycparser==2.20 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2.20)
# Requirement already satisfied: pycryptodome==3.10.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (3.10.1)
# Requirement already satisfied: pyflakes==2.3.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2.3.1)
# Requirement already satisfied: Pygments==2.9.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2.9.0)
# Requirement already satisfied: pylint==2.8.2 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2.8.2)
# Requirement already satisfied: pyparsing==2.4.7 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2.4.7)
# Requirement already satisfied: pyrsistent==0.17.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.17.3)
# Requirement already satisfied: pytest==6.2.4 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (6.2.4)
# Requirement already satisfied: python-dateutil==2.8.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2.8.1)
# Requirement already satisfied: pytz==2021.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2021.1)
# Requirement already satisfied: pyyaml==5.4.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (5.4.1)
# Requirement already satisfied: pyzmq==22.0.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (22.0.3)
# Requirement already satisfied: qtconsole==5.1.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (5.1.0)
# Requirement already satisfied: QtPy==1.9.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.9.0)
# Requirement already satisfied: regex==2021.4.4 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2021.4.4)
# Requirement already satisfied: requests==2.25.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2.25.1)
# Requirement already satisfied: scipy==1.6.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.6.3)
# Requirement already satisfied: Send2Trash==1.5.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.5.0)
# Requirement already satisfied: six==1.16.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.16.0)
# Requirement already satisfied: soupsieve==2.2.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (2.2.1)
# Requirement already satisfied: terminado==0.10.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.10.0)
# Requirement already satisfied: testpath==0.5.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.5.0)
# Requirement already satisfied: toml==0.10.2 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.10.2)
# Requirement already satisfied: tornado==6.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (6.1)
# Requirement already satisfied: tqdm==4.60.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (4.60.0)
# Requirement already satisfied: traitlets==5.0.5 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (5.0.5)
# Requirement already satisfied: typing-extensions==3.10.0.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (3.10.0.0)
# Requirement already satisfied: urllib3==1.26.5 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.26.5)
# Requirement already satisfied: wcwidth==0.2.5 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (3.5.1)
# Requirement already satisfied: wrapt==1.12.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ai-economist) (1.12.1)
# Requirement already satisfied: typed-ast<1.5,>=1.4.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from astroid==2.5.6->ai-economist) (1.4.3)
# Requirement already satisfied: importlib-metadata in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from click==8.0.1->ai-economist) (4.13.0)
# Requirement already satisfied: setuptools>=18.5 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ipython==7.31.1->ai-economist) (65.6.3)
# Requirement already satisfied: zipp>=0.5 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from importlib-metadata->click==8.0.1->ai-economist) (3.15.0)
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# Install OpenAI Gym to help define the environment's observation and action spaces for use with RLlib.

# %%
# !pip install gym==0.21
# Out:
# Collecting gym==0.21
#   Using cached gym-0.21.0-py3-none-any.whl
# Requirement already satisfied: numpy>=1.18.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from gym==0.21) (1.21.0)
# Requirement already satisfied: importlib-metadata>=4.8.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from gym==0.21) (4.13.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from gym==0.21) (2.2.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from importlib-metadata>=4.8.1->gym==0.21) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from importlib-metadata>=4.8.1->gym==0.21) (3.15.0)
# Installing collected packages: gym
# Successfully installed gym-0.21.0
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# Install the `RLlib` reinforcement learning library:
# - First, install TensorFlow
# - Then, install ray[rllib]
#
# Note: RLlib natively supports TensorFlow (including TensorFlow Eager) as well as PyTorch, but most of its internals are framework agnostic. Here's a relevant [blogpost](https://medium.com/distributed-computing-with-ray/lessons-from-implementing-12-deep-rl-algorithms-in-tf-and-pytorch-1b412009297d) that compares running RLlib algorithms with TF and PyTorch. Overall, TF seems to run a bit faster than PyTorch, in our experience, and we will use that in this notebook.

# %%
# We install these specific versions of tensorflow and rllib, that we used in our work.
#!pip install tensorflow==1.14
# !pip install "ray[rllib]==0.8.4"
# Out:
# Collecting ray[rllib]==0.8.4
#   Using cached ray-0.8.4-cp37-cp37m-manylinux1_x86_64.whl (20.2 MB)
# Requirement already satisfied: colorama in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (0.4.6)
# Requirement already satisfied: google in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (3.0.0)
# Requirement already satisfied: filelock in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (3.12.2)
# Requirement already satisfied: py-spy>=0.2.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (0.3.14)
# Requirement already satisfied: redis>=3.3.2 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (5.0.4)
# Requirement already satisfied: grpcio in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (1.62.2)
# Requirement already satisfied: pyyaml in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (5.4.1)
# Requirement already satisfied: aiohttp in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (3.8.6)
# Requirement already satisfied: numpy>=1.16 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (1.21.0)
# Requirement already satisfied: click in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (8.0.1)
# Requirement already satisfied: protobuf>=3.8.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (3.20.3)
# Requirement already satisfied: jsonschema in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (3.2.0)
# Requirement already satisfied: gym[atari] in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (0.21.0)
# Requirement already satisfied: lz4 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (3.1.3)
# Requirement already satisfied: pandas in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (1.2.4)
# Requirement already satisfied: tabulate in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (0.9.0)
# Requirement already satisfied: atari-py in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (0.2.9)
# Requirement already satisfied: dm-tree in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (0.1.8)
# Requirement already satisfied: scipy in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (1.6.3)
# Requirement already satisfied: opencv-python-headless in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (4.9.0.80)
# Requirement already satisfied: tensorboardX in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ray[rllib]==0.8.4) (2.6.2.2)
# Requirement already satisfied: typing-extensions in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from redis>=3.3.2->ray[rllib]==0.8.4) (3.10.0.0)
# Requirement already satisfied: async-timeout>=4.0.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from redis>=3.3.2->ray[rllib]==0.8.4) (4.0.3)
# Requirement already satisfied: importlib-metadata>=1.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from redis>=3.3.2->ray[rllib]==0.8.4) (4.13.0)
# Requirement already satisfied: asynctest==0.13.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from aiohttp->ray[rllib]==0.8.4) (0.13.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from aiohttp->ray[rllib]==0.8.4) (3.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from aiohttp->ray[rllib]==0.8.4) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from aiohttp->ray[rllib]==0.8.4) (21.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from aiohttp->ray[rllib]==0.8.4) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from aiohttp->ray[rllib]==0.8.4) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from aiohttp->ray[rllib]==0.8.4) (6.0.5)
# Requirement already satisfied: six in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from atari-py->ray[rllib]==0.8.4) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from google->ray[rllib]==0.8.4) (4.9.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from gym[atari]->ray[rllib]==0.8.4) (2.2.1)
# Requirement already satisfied: ale-py~=0.7.1 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from gym[atari]->ray[rllib]==0.8.4) (0.7.5)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from jsonschema->ray[rllib]==0.8.4) (0.17.3)
# Requirement already satisfied: setuptools in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from jsonschema->ray[rllib]==0.8.4) (65.6.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from pandas->ray[rllib]==0.8.4) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from pandas->ray[rllib]==0.8.4) (2021.1)
# Requirement already satisfied: packaging in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from tensorboardX->ray[rllib]==0.8.4) (20.9)
# Requirement already satisfied: importlib-resources in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from ale-py~=0.7.1->gym[atari]->ray[rllib]==0.8.4) (5.12.0)
# Requirement already satisfied: zipp>=0.5 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from importlib-metadata>=1.0->redis>=3.3.2->ray[rllib]==0.8.4) (3.15.0)
# Requirement already satisfied: idna>=2.0 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from yarl<2.0,>=1.0->aiohttp->ray[rllib]==0.8.4) (2.10)
# Requirement already satisfied: soupsieve>1.2 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from beautifulsoup4->google->ray[rllib]==0.8.4) (2.2.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (from packaging->tensorboardX->ray[rllib]==0.8.4) (2.4.7)
# Installing collected packages: ray
# Successfully installed ray-0.8.4
# WARNING: There was an error checking the latest version of pip.

# %%
# Change directory to the tutorials folder
import os, sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    os.chdir("/content/ai-economist/tutorials")
else:
    os.chdir(os.path.dirname(os.path.abspath("__file__"))
)

# %% [markdown]
# ## 1. Adding an Environment Wrapper

# %% [markdown]
# We first define a configuration (introduced in [the basics tutorial](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_basics.ipynb)) for the "gather-trade-build" environment with multiple mobile agents (that move, gather resources, build or trade) and a social planner that sets taxes according to (a scaled variant of) the 2018 US tax schedule.

# %%
# Define a configuration (dictionary) for the "gather-trade-build" environment.

env_config_dict = {
    # ===== SCENARIO CLASS =====
    # Which Scenario class to use: the class's name in the Scenario Registry (foundation.scenarios).
    # The environment object will be an instance of the Scenario class.
    'scenario_name': 'layout_from_file/simple_wood_and_stone',
    
    # ===== COMPONENTS =====
    # Which components to use (specified as list of ("component_name", {component_kwargs}) tuples).
    #   "component_name" refers to the Component class's name in the Component Registry (foundation.components)
    #   {component_kwargs} is a dictionary of kwargs passed to the Component class
    # The order in which components reset, step, and generate obs follows their listed order below.
    'components': [
        # (1) Building houses
        ('Build', {
            'skill_dist':                   'pareto', 
            'payment_max_skill_multiplier': 3,
            'build_labor':                  10,
            'payment':                      10
        }),
        # (2) Trading collectible resources
        ('ContinuousDoubleAuction', {
            'max_bid_ask':    10,
            'order_labor':    0.25,
            'max_num_orders': 5,
            'order_duration': 50
        }),
        # (3) Movement and resource collection
        ('Gather', {
            'move_labor':    1,
            'collect_labor': 1,
            'skill_dist':    'pareto'
        }),
        # (4) Planner
        ('PeriodicBracketTax', {
            'period':          100,
            'bracket_spacing': 'us-federal',
            'usd_scaling':     1000,
            'disable_taxes':   False
        })
    ],
    
    # ===== SCENARIO CLASS ARGUMENTS =====
    # (optional) kwargs that are added by the Scenario class (i.e. not defined in BaseEnvironment)
    'env_layout_file': 'quadrant_25x25_20each_30clump.txt',
    'starting_agent_coin': 10,
    'fixed_four_skill_and_loc': True,
    
    # ===== STANDARD ARGUMENTS ======
    # kwargs that are used by every Scenario class (i.e. defined in BaseEnvironment)
    'n_agents': 4,          # Number of non-planner agents (must be > 1)
    'world_size': [25, 25], # [Height, Width] of the env world
    'episode_length': 1000, # Number of timesteps per episode
    
    # In multi-action-mode, the policy selects an action for each action subspace (defined in component code).
    # Otherwise, the policy selects only 1 action.
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,
    
    # When flattening observations, concatenate scalar & vector observations before output.
    # Otherwise, return observations with minimal processing.
    'flatten_observations': True,
    # When Flattening masks, concatenate each action subspace mask into a single array.
    # Note: flatten_masks = True is required for masking action logits in the code below.
    'flatten_masks': True,
    
    # How often to save the dense logs
    'dense_log_frequency': 1,

    # new
    "env_weighting" :[0,1,.2,.4],#needs to have len of n agents
    "equ_weighting": [-2,2,4,8],
    "mobile_agent_class": "HeteroMobileAgent",#HeteroMobileAgent, BasicMobileAgent
}

# %% [markdown]
# Like we have seen in earlier [tutorials](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_basic.ipynb), using `env = foundation.make_env_instance(**env_config)` creates an environment instance `env` with the specified configuration.
#
# In order to use this environment with RLlib, we will also need to add the environment's `observation_space` and `action_space` attributes. Additionally, the environment itself must subclass the [`MultiAgentEnv`](https://github.com/ray-project/ray/blob/master/rllib/env/multi_agent_env.py) interface, which can return observations and rewards from multiple ready agents per step. To this end, we use an environment [wrapper](https://github.com/salesforce/ai-economist/blob/master/tutorials/rllib/env_wrapper.py).

# %%
# !pip install protobuf==3.20.*
# Out:
# Requirement already satisfied: protobuf==3.20.* in /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages (3.20.3)
# WARNING: There was an error checking the latest version of pip.

# %%
from rllib.env_wrapper import RLlibEnvWrapper
env_obj = RLlibEnvWrapper({"env_config_dict": env_config_dict}, verbose=True)
# Out:
# Inside covid19_components.py: 1 GPUs are available.
# Warning: The 'WarpDrive' package is not found and cannot be used! If you wish to use WarpDrive, please run 'pip install rl-warp-drive' first.
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Coin
# Stone
# Wood
# [EnvWrapper] Spaces
# [EnvWrapper] Obs (a)
# action_mask    : (50,)
# flat           : (136,)
# time           : (1,)
# world-idx_map  : (2, 11, 11)
# world-map      : (7, 11, 11)
#
#
# [EnvWrapper] Obs (p)
# action_mask    : (154,)
# flat           : (86,)
# p0             : (8,)
# p1             : (8,)
# p2             : (8,)
# p3             : (8,)
# time           : (1,)
# world-idx_map  : (2, 25, 25)
# world-map      : (6, 25, 25)
#
#
# [EnvWrapper] Action (a) Discrete(50)
# [EnvWrapper] Action (p) MultiDiscrete([22 22 22 22 22 22 22])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# Upon applying the wrapper to our environment, we have now defined observation and action spaces for the agents and the planner, indicated with `(a)` and `(p)` respectively. Also, (a useful tip) you can still access the environment instance and its attributes simply by using `env_obj.env`
#
# In summary, the observation spaces are represented as `Box` objects and the action spaces as `Discrete` objects (for more details on these types, see the OpenAI documentation [page](https://gym.openai.com/docs/#spaces)).
#
# Briefly looking at the shapes of the observation features (the numbers in parentheses), you will see that we have some one-dimensional features (e.g. `action-mask`, `flat`, `time`) as well as spatial features (e.g., `world-idx-map`, `world-map`)
#
# A couple of quick notes:
# - An `action_mask` is used to mask out the actions that are not allowed by the environment. For instance, a mobile agent cannot move beyond the boundary of the world. Hence, in position (0, 0), a mobile cannot move "Left" or "Down", and the corresponding actions in the mask would be nulled out. Now, the RL agent can still recommend to move "Left" or "Down", but the action isn't really taken.
# - The key `flat` arises since we set `flatten_observations': True`. Accordingly, the scalar and vector raw observations are all concatenated into this single key. If you're curious to see the entire set of raw observations, do set `flatten_observations': False` in the env_config, and re-run the above cell.
#
# Looking at the action spaces, the mobile agents can take 50 possible actions (including 1 NO-OP action or do nothing (always indexed 0), 44 trading-related actions, 4 move actions along the four directions and 1 build action)
#
# The planner sets the tax rates for 7 brackets, each from 0-100% in steps of 5%, so that's 21 values. Adding the NO-OP action brings the planner action space to `MultiDiscrete([22 22 22 22 22 22 22])`.

# %% [markdown]
# ## 2. Creating a *Trainer* Object

# %% [markdown]
# In order to train our economic simulation environment with RLlib, you will need familiarity with one of the key classes: the [`Trainer`](https://docs.ray.io/en/master/rllib-training.html). The trainer object maintains the relationships that connect each agent in the environment to its corresponding trainable policy, and essentially helps in training, checkpointing policies and inferring actions. It helps to co-ordinate the workflow of collecting rollouts and optimizing the various policies via a reinforcement learning algorithm. Inherently, RLlib maintains a wide suite of [algorithms](https://docs.ray.io/en/master/rllib-algorithms.html) for multi-agent learning (which was another strong reason for us to consider using RLlib) - available options include SAC, PPO, PG, A2C, A3C, IMPALA, ES, DDPG, DQN, MARWIL, APEX, and APEX_DDPG. For the remainder of this tutorial, we will stick to using [Proximal Policy Optimization](https://openai.com/blog/openai-baselines-ppo/) (PPO), an algorithm known to perform well generally.
#
# Every algorithm has a corresponding trainer object; in the context of PPO, we invoke the `PPOTrainer` object.

# %%
import ray
from ray.rllib.agents.ppo import PPOTrainer

# %% [markdown]
# PPOTrainer can be instantiated with
# - `env`: an environment creator (i.e, RLlibEnvWrapper() in our case)
# - `config`: algorithm-specific configuration data for setting the various components of the RL training loop including the environment, rollout worker processes, training resources, degree of parallelism, framework used, and the policy exploration strategies.
#
# Note: There are several configuration settings related to policy architectures, rollout collection, minibatching, and other important hyperparameters, that need to be set carefully in order to train effectively. For the sake of the high-level exposition, we allow RLlib to use most of the the default settings. Check out the list of default [common configuration parameters](https://docs.ray.io/en/releases-0.8.4/rllib-training.html#common-parameters) and default [PPO-specific configuration parameters](https://docs.ray.io/en/releases-0.8.4/rllib-algorithms.html?highlight=PPO#proximal-policy-optimization-ppo). Custom environment configurations may be passed to environment creator via `config["env_config"]`.
#
# RLlib also chooses default built-in [models](https://docs.ray.io/en/releases-0.8.4/rllib-models.html#built-in-models-and-preprocessors) for processing the observations. The models are picked based on a simple heuristic: a [vision](https://github.com/ray-project/ray/blob/master/rllib/models/tf/visionnet.py) network for observations that have shape of length larger than 2 (for example, (84 x 84 x 3)), and a [fully connected](https://github.com/ray-project/ray/blob/master/rllib/models/tf/fcnet.py) network for everything else. Custom models can be configured via the `config["policy"]["model"]` key.
#
# In the context of multi-agent training, we will also need to set the multi-agent configuration:
# ```python
# "multiagent": {
#         # Map of type MultiAgentPolicyConfigDict from policy ids to tuples
#         # of (policy_cls, obs_space, act_space, config). This defines the
#         # observation and action spaces of the policies and any extra config.
#         "policies": {},
#         # Function mapping agent ids to policy ids.
#         "policy_mapping_fn": None,
#         # Optional list of policies to train, or None for all policies.
#         "policies_to_train": None,
#     },
# ```
#
# To this end, let's notate the agent policy id by `"a"` and the planner policy id by `"p"`. We can set `policies`, `policy_mapping_fun` and `policies_to_train` as follows.

# %%
policies = {
    "a": (
        None,  # uses default policy
        env_obj.observation_space,
        env_obj.action_space,
        {}  # define a custom agent policy configuration.
    ),
    "p": (
        None,  # uses default policy
        env_obj.observation_space_pl,
        env_obj.action_space_pl,
        {}  # define a custom planner policy configuration.
    )
}

# In foundation, all the agents have integer ids and the social planner has an id of "p"
policy_mapping_fun = lambda i: "a" if str(i).isdigit() else "p"

policies_to_train = ["a", "p"]

# %% [markdown]
# Create a multiagent trainer config holding the trainable policies and their mappings.

# %%
trainer_config = {
    "multiagent": {
        "policies": policies,
        "policies_to_train": policies_to_train,
        "policy_mapping_fn": policy_mapping_fun,
    }
}

# %% [markdown]
# With distributed RL, architectures typically comprise several **roll-out** and **trainer** workers operating in tandem
# ![](assets/distributed_rl_architecture.png)
#
# The roll-out workers repeatedly step through the environment to generate and collect roll-outs in parallel, using the actions sampled from the policy models on the roll-out workers or provided by the trainer worker.
# Roll-out workers typically use CPU machines, and sometimes, GPU machines for richer environments.
# Trainer workers gather the roll-out data (asynchronously) from the roll-out workers and optimize policies on CPU or GPU machines.
#
# In this context, we can also add a `num_workers` configuration parameter to specify the number of rollout workers, i.e, those responsible for gathering rollouts. Note: setting `num_workers=0` will mean the rollouts will be collected by the trainer worker itself. Also, each worker can collect rollouts from multiple environments in parallel, which is specified in `num_envs_per_worker`; there will be a total of `num_workers` $\times$ `num_envs_per_worker` environment replicas used to gather rollouts.
# Note: below, we also update some of the default trainer settings to keep the iteration time small.

# %%
trainer_config.update(
    {
        "num_workers": 8,
        "num_envs_per_worker": 2,
        # Other training parameters
        "train_batch_size":  4000,
        "sgd_minibatch_size": 4000,
        "num_sgd_iter": 1
    }
)

# %% [markdown]
# Finally, we need to add the environment configuration to the trainer configuration.

# %%
# We also add the "num_envs_per_worker" parameter for the env. wrapper to index the environments.
env_config = {
    "env_config_dict": env_config_dict,
    "num_envs_per_worker": trainer_config.get('num_envs_per_worker'),   
}

trainer_config.update(
    {
        "env_config": env_config        
    }
)

# %% [markdown]
# One the training configuration is set, we will need to initialize ray and create the PPOTrainer object.

# %%
# Initialize Ray
ray.init(webui_host="127.0.0.1")
# Out:
# 2024-05-03 17:55:48,469	INFO resource_spec.py:212 -- Starting Ray with 31.59 GiB memory available for workers and up to 15.8 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2024-05-03 17:55:48,803	INFO services.py:1148 -- View the Ray dashboard at 127.0.0.1:8265
# {'node_ip_address': '129.132.112.254',
#  'redis_address': '129.132.112.254:36047',
#  'object_store_address': '/tmp/ray/session_2024-05-03_17-55-48_468704_414690/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2024-05-03_17-55-48_468704_414690/sockets/raylet',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': '/tmp/ray/session_2024-05-03_17-55-48_468704_414690'}

# %%
# Create the PPO trainer.
trainer = PPOTrainer(
    env=RLlibEnvWrapper,
    config=trainer_config,
    )
# Out:
# 2024-05-03 17:55:56,357	INFO trainer.py:428 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2024-05-03 17:55:56,374	INFO trainer.py:585 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# Coin
# Stone
# Wood
# Coin
# Stone
# Wood
# (pid=415088) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415088)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=415088) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415088)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=415088) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415088)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=415088) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415088)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=415088) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415088)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=415088) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415088)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=415090) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415090)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=415090) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415090)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=415090) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415090)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=415090) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415090)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=415090) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415090)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=415090) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415090)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=415088) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415088)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=415088) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415088)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=415088) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415088)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=415088) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415088)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=415088) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415088)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=415088) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415088)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=415090) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415090)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=415090) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415090)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=415090) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415090)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=415090) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415090)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=415090) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415090)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=415090) /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=415090)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=415088) Inside covid19_components.py: 1 GPUs are available.
# (pid=415088) Warning: The 'WarpDrive' package is not found and cannot be used! If you wish to use WarpDrive, please run 'pip install rl-warp-drive' first.
# (pid=415088) Coin
# (pid=415088) Stone
# (pid=415088) Wood
# (pid=415090) Inside covid19_components.py: 1 GPUs are available.
# (pid=415090) Warning: The 'WarpDrive' package is not found and cannot be used! If you wish to use WarpDrive, please run 'pip install rl-warp-drive' first.
# (pid=415090) Coin
# (pid=415090) Stone
# (pid=415090) Wood
# (pid=415088) Coin
# (pid=415088) Stone
# (pid=415088) Wood
# (pid=415090) Coin
# (pid=415090) Stone
# (pid=415090) Wood
# 2024-05-03 17:56:01,655	INFO trainable.py:217 -- Getting current IP.

# %% [markdown]
# ## 3. Perform Training

# %% [markdown]
# And that's it! We are now ready to perform training by invoking `trainer.train()`; we call it for just a few number of iterations.

# %%
NUM_ITERS = 5
for iteration in range(NUM_ITERS):
    print(f'********** Iter : {iteration} **********')
    result = trainer.train()
    print(f'''episode_reward_mean: {result.get('episode_reward_mean')}''')
# Out:
# ********** Iter : 0 **********
# episode_reward_mean: -60.87389613382571
# ********** Iter : 1 **********
# episode_reward_mean: -63.40895268570065
# ********** Iter : 2 **********
# episode_reward_mean: -65.79453561409112
# ********** Iter : 3 **********
# episode_reward_mean: -63.90007105105618
# ********** Iter : 4 **********
# episode_reward_mean: -63.39588687849416

# %%
# !tensorboard --logdir ~/ray_results/
# Out:
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/bahain/miniconda3/envs/forl/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Address already in use
# Port 6006 is in use by another program. Either identify and stop that program, or start the server with a different port.

# %% [markdown]
# By default, the results will be logged to a subdirectory of `~/ray_results`. This subdirectory will contain a file `params.json` which contains the hyperparameters, a file `result.json` which contains a training summary for each episode and a TensorBoard file that can be used to visualize training process with TensorBoard by running|
# ```shell
# tensorboard --logdir ~/ray_results
# ```

# %% [markdown]
# ## 4. Generate and Visualize the Environment's Dense Logs

# %% [markdown]
# At any point during training, we would also want to inspect the environment's dense logs in order to deep-dive into the training results. Introduced in our [basic tutorial](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_basic.ipynb#Visualize-using-dense-logging), dense logs are basically logs of each agent's states, actions and rewards at every point in time, along with a snapshot of the world state.
#
# There are two equivalent ways to fetch the environment's dense logs using the trainer object.
#
# a. Simply retrieve the dense log from the workers' environment objects
#
# b. Generate dense log(s) from the most recent trainer policy model weights

# %% [markdown]
# ### 4a. Simply retrieve the dense log from the workers' environment objects

# %% [markdown]
# From each rollout worker, it's straightforward to retrieve the dense logs using some of the function attributes.

# %%
# Below, we fetch the dense logs for each rollout worker and environment within

dense_logs = {}
# Note: worker 0 is reserved for the trainer actor
for worker in range((trainer_config["num_workers"] > 0), trainer_config["num_workers"] + 1):
    for env_id in range(trainer_config["num_envs_per_worker"]):
        dense_logs["worker={};env_id={}".format(worker, env_id)] = \
        trainer.workers.foreach_worker(lambda w: w.async_env)[worker].envs[env_id].env.previous_episode_dense_log

# %%
# We should have num_workers x num_envs_per_worker number of dense logs
print(dense_logs.keys())
# Out:
# dict_keys(['worker=1;env_id=0', 'worker=1;env_id=1', 'worker=2;env_id=0', 'worker=2;env_id=1'])

# %% [markdown]
# ### 4b. Generate a dense log from the most recent trainer policy model weights

# %% [markdown]
# We may also use the trainer object directly to play out an episode. The advantage of this approach is that we can re-sample the policy model any number of times and generate several rollouts.

# %%
def generate_rollout_from_current_trainer_policy(
    trainer, 
    env_obj,
    num_dense_logs=1
):
    dense_logs = {}
    for idx in range(num_dense_logs):
        # Set initial states
        agent_states = {}
        for agent_idx in range(env_obj.env.n_agents):
            agent_states[str(agent_idx)] = trainer.get_policy("a").get_initial_state()
        planner_states = trainer.get_policy("p").get_initial_state()   

        # Play out the episode
        obs = env_obj.reset(force_dense_logging=True)
        for t in range(env_obj.env.episode_length):
            actions = {}
            for agent_idx in range(env_obj.env.n_agents):
                # Use the trainer object directly to sample actions for each agent
                actions[str(agent_idx)] = trainer.compute_action(
                    obs[str(agent_idx)], 
                    agent_states[str(agent_idx)], 
                    policy_id="a",
                    full_fetch=False
                )

            # Action sampling for the planner
            actions["p"] = trainer.compute_action(
                obs['p'], 
                planner_states, 
                policy_id='p',
                full_fetch=False
            )

            obs, rew, done, info = env_obj.step(actions)        
            if done['__all__']:
                break
        dense_logs[idx] = env_obj.env.dense_log
    return dense_logs

# %%
dense_logs = generate_rollout_from_current_trainer_policy(
    trainer, 
    env_obj,
    num_dense_logs=2
)

# %% [markdown]
# ### Visualizing the episode dense logs

# %% [markdown]
# Once we obtain the dense logs, we can use the plotting utilities we have created to examine the episode dense logs and visualize the the world state, agent-wise quantities, movement, and trading events.

# %%
from utils import plotting  # plotting utilities for visualizing env. state

dense_log_idx = 0
plotting.breakdown(dense_logs[dense_log_idx]);
# Out:
# _______________:_ Agent  0 _____|_ Agent  1 _____|_ Agent  2 _____|_ Agent  3 ____
# Cost (Wood)    :   3.76 (n= 37) |   3.23 (n= 47) |   3.50 (n= 42) |   3.65 (n= 43)
# Cost (Stone)   :   5.26 (n= 35) |   3.92 (n= 25) |   5.05 (n= 37) |   5.27 (n= 49)
#
# Income (Wood)  :   3.59 (n= 41) |   3.54 (n= 41) |   3.52 (n= 33) |   3.46 (n= 54)
# Income (Stone) :   5.61 (n= 33) |   5.17 (n= 24) |   4.54 (n= 46) |   4.86 (n= 43)
# Income (Build) :  11.33 (n=  1) |  22.25 (n=  1) |  13.27 (n=  2) |  16.47 (n=  4)

# %%
# Shutdown Ray after use
ray.shutdown()

# %% [markdown]
# And that's it for now. See you in the [next](https://github.com/salesforce/ai-economist/blob/master/tutorials/two_level_curriculum_learning_with_rllib.md) tutorial :)
